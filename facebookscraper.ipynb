# %%
import pandas as pd
dataset = pd.read_csv('EnvNP_SG.csv')
dataset.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0             Name of organisation  \
# 0             0           0   Nature Society Singapore (NSS)
# 1             1           1                    WWF Singapore
# 2             2           2                    Zero Waste SG
# 3             3           3                          PM.Haze
# 4             4           4  Centre for a Responsible Future
#
#                          Description of organisation  \
# 0  The Nature Society (Singapore) or NSS is a non...
# 1  WWF-Singapore was founded in March 2006 to eng...
# 2  Zero Waste SG is a charity and non-governmenta...
# 3  People’s Movement to Stop Haze, known as PM Ha...
# 4  The Centre for a Responsible Future (CRF) is a...
#
#                         Mission/ Objectives/ Purpose  \
# 0  - Organise nature appreciation activities like...
# 1  SUSTAIN THE NATURAL WORLD FOR THE BENEFIT OF P...
# 2  Leading the drive towards zero waste in Singap...
# 3  Vision: We envision a world where everyone fee...
# 4  We inspire and support people and organisation...
#
#                                 Programmes/ projects  \
# 0  - guided nature walks, bird and butterfly watc...
# 1  Climate: Net-zero carbon & Sustainable finance...
# 2  1. BYO Singapore\n2. Zero Waste School\n3. Let...
# 3  1. Haze-Free Foodstand campaign\n2. Instagram ...
# 4  1. EarthFest\n2. Veganuary\n3. Community Partn...
#
#                                      Funding sources  \
# 0  Run by volunteers, the Society depends financi...
# 1  - Donations from individuals\n- Major donors \...
# 2  1. Donations\n2. Coporate funding\n3. In-kind ...
# 3  PM Haze is financially supported by the Singap...
# 4  - grants \n- business membership\n- individual...
#
#   Collaboration with government / businesses Choice of Climate action  \
# 0                          Yes -  businesses     Advocacy/ Mitigation
# 1                          Yes -  businesses     Advocacy/ Mitigation
# 2  Yes -  businesses and government agencies     Advocacy/ Mitigation
# 3              Yes -  businesses and schools     Advocacy/ Mitigation
# 4                          Yes -  businesses     Advocacy/ Mitigation
#
#   No. of employees              Geographical focus  Nationality  \
# 0               43            Singapore, Singapore          NaN
# 1              39+            Singapore, Singapore          NaN
# 2                9            Singapore, Singapore  Singaporean
# 3                9  Singapore, Indonesia, Malaysia  Singaporean
# 4                5                       Singapore  Singaporean
#
#                                        Social Medias  \
# 0  ['https://www.facebook.com/naturesocietysingap...
# 1  ['https://www.facebook.com/wwfsg/', 'https://w...
# 2  ['https://www.facebook.com/zerowastesg/', 'htt...
# 3  ['https://sg.linkedin.com/company/pm-haze', 'h...
# 4  ['https://www.facebook.com/crforgsg/', 'https:...
#
#                                     Top Google Links  \
# 0  ['https://www.nss.org.sg/', 'https://en.wikipe...
# 1  ['https://www.wwf.sg/', 'https://wwf.panda.org...
# 2  ['http://www.zerowastesg.com/', 'https://www.t...
# 3  ['https://www.pmhaze.org/', 'https://en.wikipe...
# 4  ['https://www.crf.org.sg/', 'https://www.givin...
#
#                                      New_Description  \
# 0     \r \tNature Society (Singapore)\r          ...
# 1     WWF Singapore office | WWF                 ...
# 2          Zero Waste SG – Leading the drive towa...
# 3                                                ...
# 4          Centre for a Responsible Future       ...
#
#                                   LLM_Extracted_Text
# 0  The Nature Society (Singapore) (NSS) is a lead...
# 1  WWF's Singapore office plays a crucial role in...
# 2                         Failed to fetch a response
# 3  People's Movement to Stop Haze (PMHaze) is a n...
# 4  The Centre for a Responsible Future (CRF) is a...

# %%
# !pip3 install facebook-scraper
# Out:
# Requirement already satisfied: facebook-scraper in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.2.59)
# Requirement already satisfied: dateparser<2.0.0,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from facebook-scraper) (1.2.0)
# Requirement already satisfied: demjson3<4.0.0,>=3.0.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from facebook-scraper) (3.0.6)
# Requirement already satisfied: requests-html<0.11.0,>=0.10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from facebook-scraper) (0.10.0)
# Requirement already satisfied: python-dateutil in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from dateparser<2.0.0,>=1.0.0->facebook-scraper) (2.8.2)
# Requirement already satisfied: pytz in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from dateparser<2.0.0,>=1.0.0->facebook-scraper) (2023.3)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from dateparser<2.0.0,>=1.0.0->facebook-scraper) (2023.6.3)
# Requirement already satisfied: tzlocal in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from dateparser<2.0.0,>=1.0.0->facebook-scraper) (5.2)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests-html<0.11.0,>=0.10.0->facebook-scraper) (2.31.0)
# Requirement already satisfied: pyquery in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests-html<0.11.0,>=0.10.0->facebook-scraper) (2.0.0)
# Requirement already satisfied: fake-useragent in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests-html<0.11.0,>=0.10.0->facebook-scraper) (1.4.0)
# Requirement already satisfied: parse in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests-html<0.11.0,>=0.10.0->facebook-scraper) (1.20.1)
# Requirement already satisfied: bs4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests-html<0.11.0,>=0.10.0->facebook-scraper) (0.0.2)
# Requirement already satisfied: w3lib in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests-html<0.11.0,>=0.10.0->facebook-scraper) (2.1.2)
# Requirement already satisfied: pyppeteer>=0.0.14 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests-html<0.11.0,>=0.10.0->facebook-scraper) (1.0.2)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper) (1.4.4)
# Requirement already satisfied: certifi>=2021 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper) (2023.11.17)
# Requirement already satisfied: importlib-metadata>=1.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper) (6.11.0)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper) (8.2.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper) (4.66.2)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper) (1.26.16)
# Requirement already satisfied: websockets<11.0,>=10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper) (10.4)
# Requirement already satisfied: beautifulsoup4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from bs4->requests-html<0.11.0,>=0.10.0->facebook-scraper) (4.12.3)
# Requirement already satisfied: lxml>=2.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyquery->requests-html<0.11.0,>=0.10.0->facebook-scraper) (4.9.3)
# Requirement already satisfied: cssselect>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyquery->requests-html<0.11.0,>=0.10.0->facebook-scraper) (1.2.0)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from python-dateutil->dateparser<2.0.0,>=1.0.0->facebook-scraper) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->requests-html<0.11.0,>=0.10.0->facebook-scraper) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->requests-html<0.11.0,>=0.10.0->facebook-scraper) (2.10)
# Requirement already satisfied: zipp>=0.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook-scraper) (3.17.0)
# Requirement already satisfied: soupsieve>1.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from beautifulsoup4->bs4->requests-html<0.11.0,>=0.10.0->facebook-scraper) (2.5)
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
sample_facebook_page = "https://www.facebook.com/naturesocietysingapore"

# %%
from facebook_scraper import get_profile
get_profile("naturesocietysingapore")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py:912: UserWarning: Facebook says 'Unsupported Browser'
#   warnings.warn(f"Facebook says 'Unsupported Browser'")
# {'Friend_count': None,
#  'Follower_count': None,
#  'Following_count': None,
#  'cover_photo': 'https://scontent-xsp2-1.xx.fbcdn.net/v/t39.30808-6/399319971_744345321059304_1365230365935806431_n.jpg?stp=cp0_dst-jpg_e15_fr_q65&_nc_cat=106&ccb=1-7&_nc_sid=ff2d77&_nc_ohc=bYBnpS1oVnYAX8FZsVh&_nc_ht=scontent-xsp2-1.xx&oh=00_AfArXQrHUoU7x5jk-klOwsa8EyJJd1Y_B3zj9Nhp4yBSGg&oe=65DD9A1E',
#  'profile_picture': 'https://scontent-xsp1-2.xx.fbcdn.net/v/t39.30808-1/375814919_706800321480471_4664561173937714239_n.jpg?stp=c7.7.116.116a_cp0_dst-jpg_e15_p130x130_q65&_nc_cat=101&ccb=1-7&_nc_sid=4da83f&_nc_ohc=2pNaQ-Exm5YAX9TSJry&_nc_ht=scontent-xsp1-2.xx&oh=00_AfBPnS0YSOwN7HGu5YMAohX2TDrMkIqlRP_AUlypo6eg4g&oe=65DE1980',
#  'id': '100064515291481',
#  'Name': 'Nature Society Singapore'}

# %%
from facebook_scraper import get_group_info
get_group_info("makeupartistsgroup")
# Out:
# {'id': '487581414925865',
#  'name': 'Makeup Artists',
#  'type': 'Public group',
#  'members': 4700954,
#  'about': "Are you a Makeup Artist or Upcoming or you want to learn new skills, ideas and latest trends? Join the group to learn, collaborate and share your makeup with millions of members now !\n\nIF YOU HAVE BEEN POSTING AND IT HAS NEVER BEEN APPROVED IT'S DUE TO THE FOLLOWING REASONS 👇\n\n1: Posts with links or phone number are not allowed in here UNLESS is been #PAID for.\n\n2: Post shared to the group from another group / page are highly unacceptable. It will never be approved.\n\n3: If you want to place an advert here\nKindly message Sam Ade for details.\n\nHow does the process work:\nWe provide a one-stop service to Makeup Artists, upcoming and members can simply posts photos with details, tutorials, videos, tips, ideas, questions, requests, latest trends and skills etc.\n\nWelcome to the group.\n\nWe are all from different countries and we have different styles, let's learn to tolerate each other and respect each other's.\n\n1 - First of all and very important !!!\nIf you post crypto links or scam or spam links, you'll immediately be blocked.\n\nWe have a great community and a fantastic admin team to keep this a clean and professional place to discuss makeup free from spam and scams. Please report any suspicious activity.\n\n2 - Also very important in this group !!!\nPeople are free to post what they want as long as it's makeup related if you don't like a post just ignore it, do not engage and upset people or you will be blocked, please help us keep this a safe group for our members and report any spam or scams.\n\n3 - Do not bully people in this group or you will be blocked, if you don't like a post just ignore it. AUTOMATIC REMOVAL FROM OUR GROUP FOR BULLYING.\n\nPlease don’t private message anyone on this group without asking them first on an open comment.\nAny reports of anyone doing this you will be removed and banned.\n\n\nMakeup Artists is created and admin by Sam Ade\n\nEnjoy the group and keep safe."}

# %%
# !pip3 install facebook-page-scraper
# Out:
# Collecting facebook-page-scraper
#   Downloading facebook_page_scraper-5.0.2-py3-none-any.whl.metadata (12 kB)
# Collecting selenium==4.1.0 (from facebook-page-scraper)
#   Downloading selenium-4.1.0-py3-none-any.whl (958 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 958.8/958.8 kB 11.4 MB/s eta 0:00:0000:0100:01
# Collecting webdriver-manager==3.2.2 (from facebook-page-scraper)
#   Downloading webdriver_manager-3.2.2-py2.py3-none-any.whl (16 kB)
# Collecting selenium-wire==5.1.0 (from facebook-page-scraper)
#   Downloading selenium_wire-5.1.0-py3-none-any.whl.metadata (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil==2.8.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from facebook-page-scraper) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from python-dateutil==2.8.2->facebook-page-scraper) (1.16.0)
# Requirement already satisfied: urllib3~=1.26 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from urllib3[secure]~=1.26->selenium==4.1.0->facebook-page-scraper) (1.26.16)
# Requirement already satisfied: trio~=0.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium==4.1.0->facebook-page-scraper) (0.23.1)
# Requirement already satisfied: trio-websocket~=0.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium==4.1.0->facebook-page-scraper) (0.11.1)
# Requirement already satisfied: blinker>=1.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium-wire==5.1.0->facebook-page-scraper) (1.6.2)
# Collecting brotli>=1.0.9 (from selenium-wire==5.1.0->facebook-page-scraper)
#   Downloading Brotli-1.1.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (5.5 kB)
# Requirement already satisfied: certifi>=2019.9.11 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium-wire==5.1.0->facebook-page-scraper) (2023.11.17)
# Collecting kaitaistruct>=0.7 (from selenium-wire==5.1.0->facebook-page-scraper)
#   Downloading kaitaistruct-0.10-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pyasn1>=0.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium-wire==5.1.0->facebook-page-scraper) (0.5.0)
# Requirement already satisfied: pyOpenSSL>=22.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium-wire==5.1.0->facebook-page-scraper) (23.2.0)
# Requirement already satisfied: pyparsing>=2.4.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium-wire==5.1.0->facebook-page-scraper) (3.0.9)
# Requirement already satisfied: pysocks>=1.7.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium-wire==5.1.0->facebook-page-scraper) (1.7.1)
# Requirement already satisfied: wsproto>=0.14 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium-wire==5.1.0->facebook-page-scraper) (1.2.0)
# Collecting zstandard>=0.14.1 (from selenium-wire==5.1.0->facebook-page-scraper)
#   Downloading zstandard-0.22.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.9 kB)
# Requirement already satisfied: h2>=4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium-wire==5.1.0->facebook-page-scraper) (4.1.0)
# Requirement already satisfied: hyperframe>=6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from selenium-wire==5.1.0->facebook-page-scraper) (6.0.1)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from webdriver-manager==3.2.2->facebook-page-scraper) (2.31.0)
# Collecting configparser (from webdriver-manager==3.2.2->facebook-page-scraper)
#   Downloading configparser-6.0.0-py3-none-any.whl.metadata (11 kB)
# Collecting crayons (from webdriver-manager==3.2.2->facebook-page-scraper)
#   Downloading crayons-0.4.0-py2.py3-none-any.whl (4.6 kB)
# Requirement already satisfied: hpack<5,>=4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from h2>=4.0->selenium-wire==5.1.0->facebook-page-scraper) (4.0.0)
# Requirement already satisfied: cryptography!=40.0.0,!=40.0.1,<42,>=38.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyOpenSSL>=22.0.0->selenium-wire==5.1.0->facebook-page-scraper) (41.0.2)
# Requirement already satisfied: attrs>=20.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium==4.1.0->facebook-page-scraper) (23.1.0)
# Requirement already satisfied: sortedcontainers in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium==4.1.0->facebook-page-scraper) (2.4.0)
# Requirement already satisfied: idna in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium==4.1.0->facebook-page-scraper) (2.10)
# Requirement already satisfied: outcome in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium==4.1.0->facebook-page-scraper) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from trio~=0.17->selenium==4.1.0->facebook-page-scraper) (1.3.0)
# Collecting urllib3-secure-extra (from urllib3[secure]~=1.26->selenium==4.1.0->facebook-page-scraper)
#   Downloading urllib3_secure_extra-0.1.0-py2.py3-none-any.whl.metadata (828 bytes)
# Requirement already satisfied: h11<1,>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from wsproto>=0.14->selenium-wire==5.1.0->facebook-page-scraper) (0.14.0)
# Collecting colorama (from crayons->webdriver-manager==3.2.2->facebook-page-scraper)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->webdriver-manager==3.2.2->facebook-page-scraper) (3.2.0)
# Requirement already satisfied: cffi>=1.12 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from cryptography!=40.0.0,!=40.0.1,<42,>=38.0.0->pyOpenSSL>=22.0.0->selenium-wire==5.1.0->facebook-page-scraper) (1.15.1)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from cffi>=1.12->cryptography!=40.0.0,!=40.0.1,<42,>=38.0.0->pyOpenSSL>=22.0.0->selenium-wire==5.1.0->facebook-page-scraper) (2.21)
# Downloading facebook_page_scraper-5.0.2-py3-none-any.whl (19 kB)
# Downloading selenium_wire-5.1.0-py3-none-any.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.6/239.6 kB 9.7 MB/s eta 0:00:00
# Downloading Brotli-1.1.0-cp311-cp311-macosx_10_9_universal2.whl (873 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 873.1/873.1 kB 12.1 MB/s eta 0:00:0000:0100:01
# Downloading kaitaistruct-0.10-py2.py3-none-any.whl (7.0 kB)
# Downloading zstandard-0.22.0-cp311-cp311-macosx_11_0_arm64.whl (703 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 703.4/703.4 kB 11.9 MB/s eta 0:00:00a 0:00:01
# Downloading configparser-6.0.0-py3-none-any.whl (19 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading urllib3_secure_extra-0.1.0-py2.py3-none-any.whl (1.4 kB)
# Installing collected packages: urllib3-secure-extra, brotli, zstandard, kaitaistruct, configparser, colorama, crayons, webdriver-manager, selenium, selenium-wire, facebook-page-scraper
#   Attempting uninstall: webdriver-manager
#     Found existing installation: webdriver-manager 4.0.1
#     Uninstalling webdriver-manager-4.0.1:
#       Successfully uninstalled webdriver-manager-4.0.1
#   Attempting uninstall: selenium
#     Found existing installation: selenium 4.17.2
#     Uninstalling selenium-4.17.2:
#       Successfully uninstalled selenium-4.17.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# undetected-chromedriver 3.5.4 requires selenium>=4.9.0, but you have selenium 4.1.0 which is incompatible.
# Successfully installed brotli-1.1.0 colorama-0.4.6 configparser-6.0.0 crayons-0.4.0 facebook-page-scraper-5.0.2 kaitaistruct-0.10 selenium-4.1.0 selenium-wire-5.1.0 urllib3-secure-extra-0.1.0 webdriver-manager-3.2.2 zstandard-0.22.0
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
#import Facebook_scraper class from facebook_page_scraper
from facebook_page_scraper import Facebook_scraper

#instantiate the Facebook_scraper class

page_name = "naturesocietysingapore"
posts_count = 10
browser = "firefox"
port = 10001 #ensure to rotate port 
proxy = f"137.132.26.16:{port}" #if proxy requires authentication then user:password@IP:PORT
timeout = 600 #600 seconds
headless = True
meta_ai = Facebook_scraper(page_name, posts_count, browser, proxy=proxy, timeout=timeout, headless=headless)

# %%
json_data = meta_ai.scrap_to_json()
print(json_data)
# Out:
# 2024-02-23 01:24:40,251 - facebook_page_scraper.driver_initialization - INFO - Using: 137.132.26.16:10001
# [WDM] - Driver [/Users/yuvvvvv/.wdm/drivers/geckodriver/macos/v0.34.0/geckodriver] found in cache
# {"NA": {"name": "Nature Society Singapore", "shares": 0, "reactions": {"likes": 2, "loves": 0, "wow": 0, "cares": 0, "sad": 0, "angry": 0, "haha": 0}, "reaction_count": 2, "comments": 0, "content": "", "posted_on": "2024-02-22T01:25:06.079731", "video": [], "image": ["https://scontent-xsp1-2.xx.fbcdn.net/v/t39.30808-6/428612831_807671421393360_387556226898337969_n.jpg?stp=c0.40.526.274a_cp6_dst-jpg_p526x296&_nc_cat=110&ccb=1-7&_nc_sid=d8d9c5&_nc_ohc=csfsOsQsJtsAX-E0jMx&_nc_ht=scontent-xsp1-2.xx&oh=00_AfA6usCHuD71duKYcXe90VSJuezam24vu7i0uOpKIt-__g&oe=65DBF0B1"], "post_url": "https://www.facebook.com/events/434468712300446/?__cft__[0]=AZWp6uTZKilbXH9SbyHuyT5wDEKJvYDsHammNqJotks6AyTn2v-S7Ffez_BTXG7DVlgj-ClIZXBq2vv3Q27NPoU9CAo0vIeyYfOA8kCbFVpSluorHjBXPt8GllFikwZl8YrJRsw4o2jtl22DTTAu2MJczh5KpT0WgBnG2s9Gf9rz3hQRn8z1c4bO5ALWqh-C_aW9Pg1hsblDqKnGi_yt6mG5&__tn__=%2CO%2CP-R"}, "pfbid02sbZrbs5yn3WGeNafhbs5ovbCd1VAxxDz7vLVq1RDuxhmwigqRcZG3TKjFLr7JFfjl": {"name": "Nature Society Singapore", "shares": 0, "reactions": {"likes": 14, "loves": 3, "wow": 0, "cares": 2, "sad": 0, "angry": 0, "haha": 0}, "reaction_count": 19, "comments": 1, "content": "we would like to share this hopeful video with you ...", "posted_on": "2024-02-22T01:25:06.240746", "video": ["blob:https://www.facebook.com/63ee257b-204c-4642-9e70-80b5510d426d"], "image": ["https://scontent-xsp2-1.xx.fbcdn.net/v/t15.5256-10/426133362_1493843831191843_1820090030070679311_n.jpg?stp=dst-jpg_p180x540&_nc_cat=107&ccb=1-7&_nc_sid=1a7029&_nc_ohc=h8arRIgGDTMAX9qm0MK&_nc_ht=scontent-xsp2-1.xx&oh=00_AfCeZlSKRZAuA7TSK2_xn2SW1ekpfiewUUxThVmem3wICg&oe=65DC69E9"], "post
://scontent-xsp1-2.xx.fbcdn.net/v/t39.30808-6/428187305_823842789755645_1197037110665189281_n.jpg?stp=dst-jpg_p526x296&_nc_cat=110&ccb=1-7&_nc_sid=dd5e9f&_nc_ohc=Re0zwaKj_S4AX8Eey6q&_nc_ht=scontent-xsp1-2.xx&oh=00_AfD4msIQRCu-d9qOLnn-faXXgRFtjx-5eN155aXspNNkQQ&oe=65DD5666"], "post_url": "https://www.facebook.com/naturesocietysingapore/posts/pfbid02qJL89NfqKyo4mYZbjnNyGiiQCR1QqKRsL2pVQ9K3pcSAoLTuApSyv778YmX71HXel?__cft__[0]=AZU1Y19Fg7h26NMb9CydeL3__WCjY7P-N8yxMrF9aCI6xw6Xj9VwQicnQA0EhNSh0t7uL1oxQgfeMiOLRKBSp ...

# %% [markdown]
# ### Extracts Latest Activity of Page

# %%
from pprint import pprint
pprint(json_data)
##next week:
#50 (or total) posts per organisation
#try extracting the people an organisation is following and see if that is in the list of datasets to do a network analysis
#try to get the whole following list
# Out:
# ('{"NA": {"name": "Nature Society Singapore", "shares": 0, "reactions": '
#  '{"likes": 2, "loves": 0, "wow": 0, "cares": 0, "sad": 0, "angry": 0, "haha": '
#  '0}, "reaction_count": 2, "comments": 0, "content": "", "posted_on": '
#  '"2024-02-22T01:25:06.079731", "video": [], "image": '
#  '["https://scontent-xsp1-2.xx.fbcdn.net/v/t39.30808-6/428612831_807671421393360_387556226898337969_n.jpg?stp=c0.40.526.274a_cp6_dst-jpg_p526x296&_nc_cat=110&ccb=1-7&_nc_sid=d8d9c5&_nc_ohc=csfsOsQsJtsAX-E0jMx&_nc_ht=scontent-xsp1-2.xx&oh=00_AfA6usCHuD71duKYcXe90VSJuezam24vu7i0uOpKIt-__g&oe=65DBF0B1"], '
#  '"post_url": '
#  '"https://www.facebook.com/events/434468712300446/?__cft__[0]=AZWp6uTZKilbXH9SbyHuyT5wDEKJvYDsHammNqJotks6AyTn2v-S7Ffez_BTXG7DVlgj-ClIZXBq2vv3Q27NPoU9CAo0vIeyYfOA8kCbFVpSluorHjBXPt8GllFikwZl8YrJRsw4o2jtl22DTTAu2MJczh5KpT0WgBnG2s9Gf9rz3hQRn8z1c4bO5ALWqh-C_aW9Pg1hsblDqKnGi_yt6mG5&__tn__=%2CO%2CP-R"}, '
#  '"pfbid02sbZrbs5yn3WGeNafhbs5ovbCd1VAxxDz7vLVq1RDuxhmwigqRcZG3TKjFLr7JFfjl": '
#  '{"name": "Nature Society Singapore", "shares": 0, "reactions": {"likes": 14, '
#  '"loves": 3, "wow": 0, "cares": 2, "sad": 0, "angry": 0, "haha": 0}, '
#  '"reaction_count": 19, "comments": 1, "content": "we would like to share this '
#  'hopeful video with you ...", "posted_on": "2024-02-22T01:25:06.240746", '
#  '"video": '
#  '["blob:https://www.facebook.com/63ee257b-204c-4642-9e70-80b5510d426d"], '
#  '"image": '
#  '["https://scontent-xsp2-1.xx.fbcdn.net/v/t15.5256-10/426133362_1493843831191843_1820090030070679311_n.jpg?stp=dst-jpg_p180x540&_nc_cat=107&ccb=1-7&_nc_sid=1a7029&_nc_ohc=h8arRIgGDTMAX9qm0MK&_nc_ht=scontent-xsp2-1.xx&oh=00_AfCeZlSKRZAuA7TSK2_xn2SW1ekpfiewUUxThVmem3wICg&oe=65DC69E9"], '
#  '"post_url": '
# Out:
# {'comments': 1,
#  'content': 'we would like to share this hopeful video with you ...',
#  'image': ['https://scontent-xsp2-1.xx.fbcdn.net/v/t15.5256-10/426133362_1493843831191843_1820090030070679311_n.jpg?stp=dst-jpg_p180x540&_nc_cat=107&ccb=1-7&_nc_sid=1a7029&_nc_ohc=h8arRIgGDTMAX9qm0MK&_nc_ht=scontent-xsp2-1.xx&oh=00_AfCeZlSKRZAuA7TSK2_xn2SW1ekpfiewUUxThVmem3wICg&oe=65DC69E9'],
#  'name': 'Nature Society Singapore',
#  'post_url': 'https://www.facebook.com/naturesocietysingapore/posts/pfbid02sbZrbs5yn3WGeNafhbs5ovbCd1VAxxDz7vLVq1RDuxhmwigqRcZG3TKjFLr7JFfjl?__cft__[0]=AZVQ8AhQ8Rn1XTZlsD9njM-8gR-Cg9LNIoezgRG5zx4wdPp2AGNEUEkkNMGodF8qxSrvZD8zBV0f-neTeFuVDUfias-xO3d3zrk9VJlIhzGkKf6eX_HdmwOltW0tpvwtGfMpCg3WrBFhrNeJXaGuQE1FZLs9Tq8Pyd3WLKm0S5uK5XcJXckg7JhZy_QzHOIHuyHsvBvqKzvGBQg6v8OMjKEr8iV5DQY1vzGE1S_zJ01mIxJ6aH_jKMyd9OPA3Sf7y88&__tn__=%2CO%2CP-R',
#  'posted_on': '2024-02-22T01:25:06.240746',
#  'reaction_count': 19,
#  'reactions': {'angry': 0,
#                'cares': 2,
#                'haha': 0,
#                'likes': 14,
#                'loves': 3,
#                'sad': 0,
#                'wow': 0},
#  'shares': 0,
#  'video': ['blob:https://www.facebook.com/63ee257b-204c-4642-9e70-80b5510d426d']}

# %%
sample_post = tuple_data['pfbid02sbZrbs5yn3WGeNafhbs5ovbCd1VAxxDz7vLVq1RDuxhmwigqRcZG3TKjFLr7JFfjl']
sample_post_url = tuple_data['pfbid02sbZrbs5yn3WGeNafhbs5ovbCd1VAxxDz7vLVq1RDuxhmwigqRcZG3TKjFLr7JFfjl']['post_url']
print(sample_post_url)
print(sample_post['content'])
# Out:
# https://www.facebook.com/naturesocietysingapore/posts/pfbid02sbZrbs5yn3WGeNafhbs5ovbCd1VAxxDz7vLVq1RDuxhmwigqRcZG3TKjFLr7JFfjl?__cft__[0]=AZVQ8AhQ8Rn1XTZlsD9njM-8gR-Cg9LNIoezgRG5zx4wdPp2AGNEUEkkNMGodF8qxSrvZD8zBV0f-neTeFuVDUfias-xO3d3zrk9VJlIhzGkKf6eX_HdmwOltW0tpvwtGfMpCg3WrBFhrNeJXaGuQE1FZLs9Tq8Pyd3WLKm0S5uK5XcJXckg7JhZy_QzHOIHuyHsvBvqKzvGBQg6v8OMjKEr8iV5DQY1vzGE1S_zJ01mIxJ6aH_jKMyd9OPA3Sf7y88&__tn__=%2CO%2CP-R
# we would like to share this hopeful video with you ...

# %%
import facebook_scraper as fs
MAX_COMMENTS = 100
POST_ID = "pfbid02tweoJmiqZXJeMWfEds1nzF3zeMPWoj8jBJe2AF6aJC5CTm5x5Dn3GxvPAyA5bufCl"

gen = fs.get_posts(
    post_urls=[POST_ID],
    options={"comments": MAX_COMMENTS, "progress": True}
)

post = next(gen)

# extract the comments part
comments = post['comments_full']

# process comments as you want...
for comment in comments:

    # e.g. ...print them
    pprint(comment)

    # e.g. ...get the replies for them
    for reply in comment['replies']:
        pprint(' ', reply)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py:912: UserWarning: Facebook says 'Unsupported Browser'
#   warnings.warn(f"Facebook says 'Unsupported Browser'")
#  90%|█████████ | 90/100 [00:02<00:00, 31.18it/s]
# {'comment_id': '1031064581317178',
#  'comment_image': None,
#  'comment_reaction_count': None,
#  'comment_reactions': None,
#  'comment_reactors': [],
#  'comment_text': 'I commend your love of animals surprisingly pigs are '
#                  'exceptionally intelligent and make great pets just like dogs '
#                  'nice one Arnie. Says me eating a bacon sarnie 😂',
#  'comment_time': datetime.datetime(2024, 1, 23, 0, 0),
#  'comment_url': 'https://facebook.com/1031064581317178',
#  'commenter_id': '1361317998',
#  'commenter_meta': None,
#  'commenter_name': 'Bob Leary',
#  'commenter_url': None,
#  'replies': [{'comment_id': '774703554471211',
#               'comment_image': None,
#               'comment_reaction_count': None,
#               'comment_reactions': None,
#               'comment_reactors': [],
#               'comment_text': 'Bob Leary Speaking from experience, adding '
#                               'passive income to my portfolio has indeed '
#                               'helped me increase my earning. Crypto trading '
#                               'is a way to generate passive income and grow '
#                               'one’s finances. Interested in knowing more '
#                               'about this strategy and how it works, click on '
#                               'the name below and contact Mr Richard Donald, '
#                               'He is a certified experienced trader.\n'
#                               '👇 👇\n'
#                               'Richard Donald',
#               'comment_time': datetime.datetime(2024, 1, 23, 0, 0),
#               'comment_url': 'https://facebook.com/774703554471211',
#               'commenter_id': '61555300957355',
#               'commenter_meta': None,
#               'commenter_name': 'Asaiah Zamir',
#               'commenter_url': None},
#              {'comment_id': '1447245652497307',
#               'comment_image': 'https://t.me/Official_ArnoIdschwarzenegger',
#               'comment_reaction_count': None,
#               'comment_reactions': None,
#               'comment_reactors': [],
#               'comment_text': 'Bob Leary Hey friend, good day, hope your day '
#                               'is going well? Well I actually had a chance to '
#                               'chat with Arnold Schwarzenegger on telegram. '
#                               'He’s verified there and that’s what you would '
#                               'use to differentiate the real one and the fake '
#                               'one. You can check on his telegram account to '
#                               'see for yourself. Don’t tell him I gave you his '
#                               'private telegram link to chat up with him, '
#                               'here’s the link\n'
#                               'https://t.me/\n'
#                               'Official_ArnoIds\n'
#                               'chwarzenegger',
#               'comment_time': datetime.datetime(2024, 1, 23, 0, 0),
#               'comment_url': 'https://facebook.com/1447245652497307',
#               'commenter_id': '100082173264889',
#               'commenter_meta': None,
#               'commenter_name': 'Bonnie Akers',
#               'commenter_url': None},
#              {'comment_id': '398340839286142',
#               'comment_image': None,
#               'comment_reaction_count': None,
#               'comment_reactions': None,
#               'comment_reactors': [],
#               'comment_text': 'Bonnie Akers\n'
#                               'Not spoken to Arnold for just over 40years when '
#                               'he was at my local gym (Leeds UK) and stayed at '
#                               'my pals house who owned the gym, I help look '
#                               'after him for around a week. But not sure about '
#                               'using again.',
#               'comment_time': datetime.datetime(2024, 1, 23, 0, 0),
#               'comment_url': 'https://facebook.com/398340839286142',
#               'commenter_id': '1361317998',
#               'commenter_meta': None,
#               'commenter_name': 'Bob Leary',
#               'commenter_url': None},
#              {'comment_id': '1421821758712325',
#               'comment_image': 'https://t.me/Arnold_Schwarzenegger0',
#               'comment_reaction_count': None,
#               'comment_reactions': None,
#               'comment_reactors': [],
#               'comment_text': 'Bob Leary Mr Arnold Schwarzenegger finally '
#                               'created a private page recently because he '
#                               'wanted to put an end to impersonation from '
#                               "people claiming to be him, don't be scammed "
#                               'ok.sending him a direct message on Telegram '
#                               'application through the link below👇, you might '
#                               'lucky to get a response back from him just like '
#                               'I did. https://t.me/\n'
#                               'Arnold_Schwarzen\n'
#                               'egger0',
#               'comment_time': datetime.datetime(2024, 1, 23, 0, 0),
#               'comment_url': 'https://facebook.com/1421821758712325',
#               'commenter_id': '100079669208925',
#               'commenter_meta': None,
#               'commenter_name': 'Desiree Martinez',
#               'commenter_url': None},
#              {'comment_id': '360355563298305',
#               'comment_image': 'https://uply.pro/crZY5',
#               'comment_reaction_count': None,
#               'comment_reactions': None,
#               'comment_reactors': [],
#               'comment_text': 'Bob Leary Sign up and complete market research '
#                               'surveys, sign up for brand name offers & You '
#                               'earn points for each activity that you complete '
#                               'and it is free to participate! https://\n'
#                               'uply.pro/crZY5',
#               'comment_time': datetime.datetime(2024, 1, 23, 0, 0),
#               'comment_url': 'https://facebook.com/360355563298305',
#               'commenter_id': '100085320426068',
#               'commenter_meta': None,
#               'commenter_name': 'Michle Huges',
#               'commenter_url': None},
#              {'comment_id': '726490629216426',
#               'comment_image': 'https://rb.gy/21fxnv',
#               'comment_reaction_count': None,
#               'comment_reactions': None,
#               'comment_reactors': [],
#               'comment_text': 'Bob Leary Take Surveys & Get FREE The Home '
#                               'Depot Gift Card\n'
#                               'https://rb.gy/\n'
#                               '21fxnv',
#               'comment_time': datetime.datetime(2024, 1, 23, 0, 0),
#               'comment_url': 'https://facebook.com/726490629216426',
#               'commenter_id': '100009059101823',
#               'commenter_meta': None,
#               'commenter_name': 'চাঁদের হাসি',
#               'commenter_url': None},
#              {'comment_id': '1336361470358127',
#               'comment_image': None,
#               'comment_reaction_count': None,
#               'comment_reactions': None,
#               'comment_reactors': [],
#               'comment_text': "Bob Leary hello handsome what's up how are you "
#                               'doing today',
#               'comment_time': datetime.datetime(2024, 1, 23, 0, 0),
#               'comment_url': 'https://facebook.com/1336361470358127',
#               'commenter_id': '61551201833050',
#               'commenter_meta': None,
#               'commenter_name': 'Sharon Beaty',
#               'commenter_url': None},
#              {'comment_id': '921474959334809',
#               'comment_image': 'https://wa.me/message/N37HVZ7ZYVHWN1',
#               'comment_reaction_count': None,
#               'comment_reactions': None,
#               'comment_reactors': [],
#               'comment_text': 'Bob Leary Congratulations\n'
#                               '! You are among the people to whom the Dwayne '
#                               'Johnson Foundation wishes to offer gifts. '
#                               'Please contact the number below to claim your '
#                               'prize 👇👇👇👇👇👇👇👇https://wa.me/\n'
#                               'message/\n'
#                               'N37HVZ7ZYVHWN1',
#               'comment_time': datetime.datetime(2024, 1, 23, 0, 0),
#               'comment_url': 'https://facebook.com/921474959334809',
#               'commenter_id': '100075055474148',
#               'commenter_meta': None,
#               'commenter_name': 'Yasmina Pombert',
#               'commenter_url': None},
#              {'comment_id': '354365550781702',
#               'comment_image': 'https://uply.pro/Mct2a',
#               'comment_reaction_count': None,
#               'comment_reactions': None,
#               'comment_reactors': [],
#               'comment_text': 'Bob Leary Get More With American Express Gift '
#                               'Cards !! https://\n'
#                               'uply.pro/Mct2a',
#               'comment_time': datetime.datetime(2024, 1, 23, 0, 0),
#               'comment_url': 'https://facebook.com/354365550781702',
#               'commenter_id': '61555684473854',
#               'commenter_meta': None,
#               'commenter_name': 'Diane Young',
#               'commenter_url': None},
#              {'comment_id': '1177296663255045',
#               'comment_image': 'https://uply.pro/Ng73b',
#               'comment_reaction_count': None,
#               'comment_reactions': None,
#               'comment_reactors': [],
#               'comment_text': 'Bob Leary Take Surveys &Get FREE Nike Gift Card '
#                               'Earn Points\n'
#                               'https://\n'
#                               'uply.pro/Ng73b',
#               'comment_time': datetime.datetime(2024, 1, 23, 0, 0),
#               'comment_url': 'https://facebook.com/1177296663255045',
#               'commenter_id': '61554699155388',
#               'commenter_meta': None,
#               'commenter_name': 'Mic Hael',
#               'commenter_url': None},
#              {'comment_id': '1232684934756623',
#               'comment_image': None,
#               'comment_reaction_count': None,
#               'comment_reactions': None,
#               'comment_reactors': [],
#               'comment_text': 'Bob Leary https://\n'
#                               'www.facebook.com\n'
#                               '/groups/\n'
#                               '331869886132678/\n'
#                               '?ref=share_group\n'
#                               '_link',
#               'comment_time': datetime.datetime(2024, 1, 23, 0, 0),
#               'comment_url': 'https://facebook.com/1232684934756623',
#               'commenter_id': '61554101515359',
#               'commenter_meta': None,
#               'commenter_name': 'Thomas Philip',
#               'commenter_url': None},
#              {'comment_id': '1527185928058381',
#               'comment_image': None,
#               'comment_reaction_count': None,
#               'comment_reactions': None,
#               'comment_reactors': [],
#               'comment_text': 'Bob',
#               'comment_time': datetime.datetime(2024, 1, 23, 0, 0),
#               'comment_url': 'https://facebook.com/1527185928058381',
#               'commenter_id': '100000013850442',
#               'commenter_meta': None,
#               'commenter_name': 'Pavel Korec',
#               'commenter_url': None},
#              {'comment_id': '1468143547415026',
#               'comment_image': None,
#               'comment_reaction_count': None,
#               'comment_reactions': None,
#               'comment_reactors': [],
#               'comment_text': 'Bob Leary https://\n'
#                               'www.facebook.com\n'
#                               '/groups/\n'
#                               '364026536237668/\n'
#                               '?ref=share_group\n'
#                               '_link',
#               'comment_time': datetime.datetime(2024, 1, 23, 0, 0),
#               'comment_url': 'https://facebook.com/1468143547415026',
#               'commenter_id': '100030624314239',
#               'commenter_meta': None,
#               'commenter_name': 'Smith Jason',
#               'commenter_url': None},
#              {'comment_id': '349808494529612',
#               'comment_image': None,
#               'comment_reaction_count': None,
#               'comment_reactions': None,
#               'comment_reactors': [],
#               'comment_text': 'Bob Leary https://\n'
#                               'www.facebook.com\n'
#                               '/groups/\n'
#                               '331869886132678/\n'
#                               '?ref=share_group\n'
#                               '_link',
#               'comment_time': datetime.datetime(2024, 1, 23, 0, 0),
#               'comment_url': 'https://facebook.com/349808494529612',
#               'commenter_id': '61553666591810',
#               'commenter_meta': None,
#               'commenter_name': 'Arnold Gray',
#               'commenter_url': None},
#              {'comment_id': '757409689149614',
#               'comment_image': None,
#               'comment_reaction_count': None,
#               'comment_reactions': None,
#               'comment_reactors': [],
#               'comment_text': 'Guess what? Arnold Schwarzenegger has actually '
#                               'provided her private page link below! You can '
#                               'send her heartfelt D M and see what happens.Go '
#                               "ahead and give it a shot, and don't forget to "
#                               'thank me later!\n'
#                               'https://\n'
#                               'web.facebook.com\n'
#                               '/\n'
#                               'profile.php?id=6\n'
#                               '1556128881937',
#               'comment_time': datetime.datetime(2024, 1, 23, 0, 0),
#               'comment_url': 'https://facebook.com/757409689149614',
#               'commenter_id': '100080265316989',
#               'commenter_meta': None,
#               'commenter_name': 'Jennyfer Robertn',
#               'commenter_url': None},
#              {'comment_id': '1468793917033175',
#               'comment_image': 'https://media.tenor.co/L7ASYp4pNHcAAAAM/you-are-so-stupid-amy-lau.gif?c=VjFfZmFjZWJvb2s&t=AAYPutJ6DOwFCC-CuQnJCA',
#               'comment_reaction_count': None,
#               'comment_reactions': None,
#               'comment_reactors': [],
#               'comment_text': 'Bob Leary 🙄',
#               'comment_time': datetime.datetime(2024, 1, 23, 0, 0),
#               'comment_url': 'https://facebook.com/1468793917033175',
#               'commenter_id': '100029869098055',
#               'commenter_meta': None,
#               'commenter_name': 'Alma Cuervo',
#               'commenter_url': None},
#              {'comment_id': '767085031953191',
#               'comment_image': None,
#               'comment_reaction_count': None,
#               'comment_reactions': None,
#               'comment_reactors': [],
#               'comment_text': 'Bob Leary Thank you for your love and support, '
#                               "Click on my profile and send me a message let's "
#                               'chat private on my VIP fans page',
#               'comment_time': datetime.datetime(2024, 1, 23, 0, 0),
#               'comment_url': 'https://facebook.com/767085031953191',
#               'commenter_id': '100088746854610',
#               'commenter_meta': None,
#               'commenter_name': 'Larry Wang Lee',
#               'commenter_url': None},
#              {'comment_id': '1232113547747453',
#               'comment_image': 'https://wa.me/message/PBFWRELDFOAHG1',
#               'comment_reaction_count': None,
#               'comment_reactions': None,
#               'comment_reactors': [],
#               'comment_text': 'Bob Leary Well done !!!\n'
#                               '\n'
#                               'Congratulations\n'
#                               'to you 👏\n'
#                               '\n'
#                               'To distribute gifts to these fans this start of '
#                               'the New Year, actor Keanu Charles Reevers has '
#                               'you choose from among the (25) winners. So you '
#                               'are the winner of a Rang Rover car, an Iphone '
#                               '13 pro Max and a sum of $350,000 which will be '
#                               'transported to you by the FedEx Company. So '
#                               'write to the director of the FedEx Company to '
#                               'claim your gifts via this link https://wa.me/\n'
#                               'message/\n'
#                               'PBFWRELDFOAHG1',
#               'comment_time': datetime.datetime(2024, 1, 23, 0, 0),
#               'comment_url': 'https://facebook.com/1232113547747453',
#               'commenter_id': '100090547525245',
#               'commenter_meta': None,
#               'commenter_name': "Eclamo's Hêptôs",
#               'commenter_url': None},
#              {'comment_id': '742156304262802',
#               'comment_image': None,
#               'comment_reaction_count': None,
#               'comment_reactions': None,
#               'comment_reactors': [],
#               'comment_text': 'Aurillac Germany SCAM',
#               'comment_time': datetime.datetime(2024, 1, 23, 0, 0),
#               'comment_url': 'https://facebook.com/742156304262802',
#               'commenter_id': '1361317998',
#               'commenter_meta': None,
#               'commenter_name': 'Bob Leary',
#               'commenter_url': None},
#              {'comment_id': '936647564468019',
#               'comment_image': None,
#               'comment_reaction_count': None,
#               'comment_reactions': None,
#               'comment_reactors': [],
#               'comment_text': 'Bob Leary ???',
#               'comment_time': datetime.datetime(2024, 1, 23, 0, 0),
#               'comment_url': 'https://facebook.com/936647564468019',
#               'commenter_id': '100090547525245',
#               'commenter_meta': None,
#               'commenter_name': "Eclamo's Hêptôs",
#               'commenter_url': None},
#              {'comment_id': '407718038451836',
#               'comment_image': None,
#               'comment_reaction_count': None,
#               'comment_reactions': None,
#               'comment_reactors': [],
#               'comment_text': 'Bob Leary Hello I was just searching for an old '
#                               'friend here on Facebook when i came across your '
#                               'profile... And I thought you seemed worth '
#                               "talking to I hope you don't mind us getting to "
#                               'know more about ourselves....',
#               'comment_time': datetime.datetime(2024, 2, 9, 0, 0),
#               'comment_url': 'https://facebook.com/407718038451836',
#               'commenter_id': '100094265382297',
#               'commenter_meta': None,
#               'commenter_name': 'Elizabeth Jones',
#               'commenter_url': None},
#              {'comment_id': '913026320148472',
#               'comment_image': None,
#               'comment_reaction_count': None,
#               'comment_reactions': None,
#               'comment_reactors': [],
#               'comment_text': 'Elizabeth Jones 👍',
#               'comment_time': datetime.datetime(2024, 2, 9, 0, 0),
#               'comment_url': 'https://facebook.com/913026320148472',
#               'commenter_id': '1361317998',
#               'commenter_meta': None,
#               'commenter_name': 'Bob Leary',
#               'commenter_url': None},
#              {'comment_id': '916898753552045',
#               'comment_image': None,
#               'comment_reaction_count': None,
#               'comment_reactions': None,
#               'comment_reactors': [],
#               'comment_text': 'Bob Leary Add me up',
#               'comment_time': datetime.datetime(2024, 2, 9, 0, 0),
#               'comment_url': 'https://facebook.com/916898753552045',
#               'commenter_id': '100094265382297',
#               'commenter_meta': None,
#               'commenter_name': 'Elizabeth Jones',
#               'commenter_url': None},
#              {'comment_id': '301481519212924',
#               'comment_image': None,
#               'comment_reaction_count': None,
#               'comment_reactions': None,
#               'comment_reactors': [],
#               'comment_text': 'Jake Aston I see your point of view and I '
#                               "probably eat bacon once a month and I'm "
#                               "particular where it's farmed and raised, I've "
#                               "virtually stopped eating red meat and I don't "
#                               'eat as much white meat as I used too. Whatever '
#                               'we eat has an impact on some poor creatures '
#                               'whether it is directly or directly.',
#               'comment_time': datetime.datetime(2024, 2, 9, 0, 0),
#               'comment_url': 'https://facebook.com/301481519212924',
#               'commenter_id': '1361317998',
#               'commenter_meta': None,
#               'commenter_name': 'Bob Leary',
#               'commenter_url': None},
#              {'comment_id': '407139948554608',
#               'comment_image': None,
#               'comment_reaction_count': None,
#               'comment_reactions': None,
#               'comment_reactors': [],
#               'comment_text': "Bob Leary I'm glad to hear you've been cutting "
#                               'down on your meat consumption! And I do agree '
#                               "with you that it's currently impossible to have "
#                               'a 100% harmless diet... However, the most '
#                               'significant way to reduce your harm to animals '
#                               'and the environment is to eat a completely '
#                               'plant-based diet.\n'
#                               '\n'
#                               "This is because any harm that's caused by crop "
#                               'production is hugely increased when we grow '
#                               'crops to feed billions of farmed animals. And '
#                               'then we obviously kill all those farmed animals '
#                               'for meat. If we just ate the plant food '
#                               'directly, there would be far less harm '
#                               'overall.\n'
#                               '\n'
#                               "So if you're like me and you believe that we "
#                               'should do our best to treat animals with '
#                               'respect, then the best thing you can do is cut '
#                               'out meat all together. ✌😊',
#               'comment_time': datetime.datetime(2024, 2, 9, 0, 0),
#               'comment_url': 'https://facebook.com/407139948554608',
#               'commenter_id': '1491216600',
#               'commenter_meta': None,
#               'commenter_name': 'Jake Aston',
#               'commenter_url': None}]}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[60], line 23
#      21 # e.g. ...get the replies for them
#      22 for reply in comment['replies']:
# ---> 23     pprint(' ', reply)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/pprint.py:55, in pprint(object, stream, indent, width, depth, compact, sort_dicts, underscore_numbers)
#      50 """Pretty-print a Python object to a stream [default is sys.stdout]."""
#      51 printer = PrettyPrinter(
#      52     stream=stream, indent=indent, width=width, depth=depth,
#      53     compact=compact, sort_dicts=sort_dicts,
#      54     underscore_numbers=underscore_numbers)
# ---> 55 printer.pprint(object)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/pprint.py:153, in PrettyPrinter.pprint(self, object)
#     151 def pprint(self, object):
#     152     if self._stream is not None:
# --> 153         self._format(object, self._stream, 0, 0, {}, 0)
#     154         self._stream.write("\n")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/pprint.py:194, in PrettyPrinter._format(self, object, stream, indent, allowance, context, level)
#     192         del context[objid]
#     193         return
# --> 194 stream.write(rep)
#
# AttributeError: 'dict' object has no attribute 'write'

# %%
import facebook_scraper as fs
MAX_COMMENTS = 100
POST_ID = "pfbid02sbZrbs5yn3WGeNafhbs5ovbCd1VAxxDz7vLVq1RDuxhmwigqRcZG3TKjFLr7JFfjl"

gen = fs.get_posts(
    post_urls=[POST_ID],
    options={"comments": MAX_COMMENTS, "progress": True}
)

post = next(gen)

# extract the comments part
comments = post['comments_full']

# process comments as you want...
for comment in comments:

    # e.g. ...print them
    pprint(comment)

    # e.g. ...get the replies for them
    for reply in comment['replies']:
        pprint(' ', reply)
#no of average interactions per post -> statistics to gauge engagement 
#run statistics about facebook account for all of the datasets
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/facebook_scraper/facebook_scraper.py:912: UserWarning: Facebook says 'Unsupported Browser'
#   warnings.warn(f"Facebook says 'Unsupported Browser'")
#   0%|          | 0/100 [00:00<?, ?it/s]
# {'comment_id': '380264228044930',
#  'comment_image': None,
#  'comment_reaction_count': None,
#  'comment_reactions': None,
#  'comment_reactors': [],
#  'comment_text': 'Ian Jones Isaac Jones 😍',
#  'comment_time': datetime.datetime(2024, 2, 20, 0, 0),
#  'comment_url': 'https://facebook.com/380264228044930',
#  'commenter_id': '792135313',
#  'commenter_meta': None,
#  'commenter_name': 'Claire Jones',
#  'commenter_url': None,
#  'replies': []}

# %%
sample_link = f'www.facebook.com/{POST_ID}'

# %%
import requests
from bs4 import BeautifulSoup

class FaceBookBot():
    login_basic_url = 'https://www.facebook.com'
    login_mobile_url = 'https://m.facebook.com/login'

    post_ID = ""

    def parse_html(self, request_url):
        with requests.Session() as session:
            post = session.post(self.login_basic_url)
            parsed_html = session.get(request_url)
        return parsed_html

    def post_content(self):
        REQUEST_URL = f'https://mbasic.facebook.com/story.php?story_fbid={self.post_ID}&id=415518858611168'
        
        soup = BeautifulSoup(self.parse_html(REQUEST_URL).content, "html.parser")
        content = soup.find_all('p')
        post_content = []
        for lines in content:
            post_content.append(lines.text)
        
        post_content = ' '.join(post_content)    
        return post_content

    def date_posted(self):
        REQUEST_URL = f'https://mbasic.facebook.com/story.php?story_fbid={self.post_ID}&id=415518858611168'
        
        soup = BeautifulSoup(self.parse_html(REQUEST_URL).content, "html.parser")
        date_posted = soup.find('abbr')
        return date_posted.text

    def post_likes(self):
        limit = 200
        REQUEST_URL = f'https://mbasic.facebook.com/ufi/reaction/profile/browser/fetch/?limit={limit}&total_count=17&ft_ent_identifier={self.post_ID}'

        soup = BeautifulSoup(self.parse_html(REQUEST_URL).content, "html.parser")
        names = soup.find_all('h3')
        people_who_liked = []
        for name in names:
            people_who_liked.append(name.text)
        people_who_liked = [i for i in people_who_liked if i] 
        return people_who_liked

    def post_shares(self):        
        REQUEST_URL = f'https://m.facebook.com/browse/shares?id={self.post_ID}'
        
        with requests.Session() as session:
            post = session.post(self.login_mobile_url, data=self.payload)
            parsed_html = session.get(REQUEST_URL)
        
        soup = BeautifulSoup(parsed_html.content, "html.parser")
        names = soup.find_all('span')
        people_who_shared = []
        for name in names:
            people_who_shared.append(name.text)
        return people_who_shared

# %%
import requests
import random

from time import sleep
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options


class FaceBookBot():

    def __init__(self):
        options = webdriver.ChromeOptions()
        options.add_argument('--disable-notifications')
        self.driver = webdriver.Chrome(options=options)

    def login(self,username, password):
        self.driver.get("https://www.facebook.com/login")

        sleep(2)

        email_in = self.driver.find_element_by_xpath('//*[@id="email"]')
        email_in.send_keys(username)

        password_in = self.driver.find_element_by_xpath('//*[@id="pass"]')
        password_in.send_keys(password)

        login_btn = self.driver.find_element_by_xpath('//*[@id="loginbutton"]')
        login_btn.click()

        sleep(2)



    def log_in_basic(self):
        POST_LOGIN_URL = 'https://mbasic.facebook.com/login'

        payload = {
            'email': username,
            'pass': password
        }

        with requests.Session() as session:
            post = session.post(POST_LOGIN_URL, data=payload)

    def post_likes(self):
        #This URL will be the URL that your login form points to with the "action" tag.
        POST_LOGIN_URL = 'https://mbasic.facebook.com/login'

        #This URL is the page you actually want to pull down with requests.
        post_ID = 'the-post-ID'
        limit = 200
        REQUEST_URL = f'https://mbasic.facebook.com/ufi/reaction/profile/browser/fetch/?limit={limit}&total_count=17&ft_ent_identifier={post_ID}'

        payload = {
            'email': username,
            'pass': password
        }

        with requests.Session() as session:
            post = session.post(POST_LOGIN_URL, data=payload)
            r = session.get(REQUEST_URL)
        soup = BeautifulSoup(r.content, "html.parser")
        names = soup.find_all('h3', class_='be')
        people_who_liked = []
        for name in names:
            people_who_liked.append(name.text)

        return people_who_liked

    def post_shares(self):
        #This URL will be the URL that your login form points to with the "action" tag.
        POST_LOGIN_URL = 'https://mbasic.facebook.com/login'

        post_ID = 'the-post-ID'
        #This URL is the page you actually want to pull down with requests.
        REQUEST_URL = f'https://m.facebook.com/browse/shares?id={post_ID}'

        payload = {
            'email': username,
            'pass': password
        }

        with requests.Session() as session:
            post = session.post(POST_LOGIN_URL, data=payload)
            r = session.get(REQUEST_URL)
        soup = BeautifulSoup(r.content, "html.parser")
        names = soup.find_all('span')
        people_who_shared = []
        for name in names:
            people_who_shared.append(name.text)

        return people_who_shared

    def page_likes(self):
        self.login(username, password)

        page_name = "nature"
        # This URL is the page you actually want to pull down with requests.
        REQUEST_URL = f'https://www.facebook.com/{page_name}/settings/?tab=people_and_other_pages&ref=page_edit'

        self.driver.get(REQUEST_URL)

        sleep(2)

        for i in range(1,15):
            self.driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            sleep(3)

        page = self.driver.page_source
        soup = BeautifulSoup(page, "html.parser")
        names = soup.find_all('a', class_='_3cb8')
        people_who_liked_page = []
        for name in names:
            people_who_liked_page.append(name.text)

        return people_who_liked_page

    def select_winner(self,list_A,list_B,list_C):
        eligible_to_win = []
        for name in list_A:
            if name in list_B and name in list_C:
                eligible_to_win.append(name)
        return eligible_to_win

bot = FaceBookBot()
people_who_follow = bot.page_likes()
people_who_liked = bot.post_likes()
people_who_shared = bot.post_shares()

eligible = bot.select_winner(people_who_liked,people_who_follow,people_who_shared)
winner = random.choice(eligible)
print(winner)
